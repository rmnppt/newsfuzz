# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
from bs4 import BeautifulSoup
import requests
import numpy as np

# %%
# Fetch the data from the mysql server and throw it into a dataframe
engine = create_engine('mysql+pymysql://newsfuzz:newsfuzzplease@newsfuzz.cuhvcgseshha.eu-west-2.rds.amazonaws.com:3306/newsfuzz', encoding='utf-8')
newsfuzz_db = pd.io.sql.read_sql('SELECT * FROM newsfuzz_db_test', engine, index_col='index')

# %%
print(len(newsfuzz_db))
newsfuzz_db.head()
# Out:
# 12566
#                                           article_author  \
# index
# 0                                                   None
# 1                                                   None
# 2        http://www.abc.net.au/news/james-glenday/167008
# 3      http://www.abc.net.au/news/rural/sparkes-david...
# 4                                                   None
#
#                                      article_description  \
# index
# 0      Nearly 900 Australians have been recognised fo...
# 1      Senior British ministers have backed beleaguer...
# 2      Theresa May's authority in Westminster is stil...
# 3      Kai Hao, the innocent man killed in the Bright...
# 4      The bodies of two sisters, aged 10 and 13, are...
#
#         article_publishedAt  \
# index
# 0      2017-06-11T14:27:12Z
# 1      2017-06-11T11:37:25Z
# 2      2017-06-11T09:14:03Z
# 3      2017-06-11T10:40:32Z
# 4      2017-06-11T08:18:31Z
#
#                                              article_raw  \
# index
# 0      Cate Blanchett Antony Green Alan Joyce among Q...
# 1      Theresa May s leadership on the line as Conser...
# 2      Theresa May s leadership peril long term after...
# 3      Brighton siege victim Nick Hao remembered at s...
# 4      Sisters die after bedroom catches fire in Tasm...
#
#                                            article_title  \
# index
# 0      Meet the Aussies on this year's Queen's Birthd...
# 1      Ministers back under pressure British PM amid ...
# 2      May 'a caretaker prime minister' after electio...
# 3      Brighton siege victim remembered as family man...
# 4        Sisters die after detached bedroom catches fire
#
#                                              article_url  \
# index
# 0      http://www.abc.net.au/news/2017-06-12/queens-b...
# 1      http://www.abc.net.au/news/2017-06-11/theresa-...
# 2      http://www.abc.net.au/news/2017-06-11/theresa-...
# 3      http://www.abc.net.au/news/2017-06-11/funeral-...
# 4      http://www.abc.net.au/news/2017-06-11/tasmania...
#
#                                       article_urlToImage source_category  \
# index
# 0      http://www.abc.net.au/news/image/8607172-1x1-7...         general
# 1      http://www.abc.net.au/news/image/8609126-1x1-7...         general
# 2      http://www.abc.net.au/news/image/7896330-1x1-7...         general
# 3      http://www.abc.net.au/news/image/8598506-1x1-7...         general
# 4      http://www.abc.net.au/news/image/8609118-1x1-7...         general
#
#       source_country                                 source_description  \
# index
# 0                 au  Australia's most trusted source of local, nati...
# 1                 au  Australia's most trusted source of local, nati...
# 2                 au  Australia's most trusted source of local, nati...
# 3                 au  Australia's most trusted source of local, nati...
# 4                 au  Australia's most trusted source of local, nati...
#
#          source_id source_language    source_name                  source_url
# index
# 0      abc-news-au              en  ABC News (AU)  http://www.abc.net.au/news
# 1      abc-news-au              en  ABC News (AU)  http://www.abc.net.au/news
# 2      abc-news-au              en  ABC News (AU)  http://www.abc.net.au/news
# 3      abc-news-au              en  ABC News (AU)  http://www.abc.net.au/news
# 4      abc-news-au              en  ABC News (AU)  http://www.abc.net.au/news

# %%
np.unique(newsfuzz_db['source_id'])
# Out:
# array(['abc-news-au', 'al-jazeera-english', 'ars-technica',
#        'associated-press', 'bbc-news', 'bbc-sport', 'bild', 'bloomberg',
#        'breitbart-news', 'business-insider', 'business-insider-uk',
#        'buzzfeed', 'cnbc', 'cnn', 'daily-mail', 'engadget',
#        'entertainment-weekly', 'espn', 'espn-cric-info', 'financial-times',
#        'focus', 'football-italia', 'fortune', 'four-four-two',
#        'fox-sports', 'google-news', 'gruenderszene', 'hacker-news', 'ign',
#        'independent', 'mashable', 'metro', 'mirror', 'mtv-news',
#        'mtv-news-uk', 'national-geographic', 'new-scientist',
#        'new-york-magazine', 'newsweek', 'nfl-news', 'polygon', 'recode',
#        'reddit-r-all', 'reuters', 'spiegel-online', 't3n', 'talksport',
#        'techcrunch', 'techradar', 'the-economist', 'the-guardian-au',
#        'the-guardian-uk', 'the-hindu', 'the-huffington-post',
#        'the-lad-bible', 'the-new-york-times', 'the-sport-bible',
#        'the-telegraph', 'the-times-of-india', 'the-verge',
#        'the-wall-street-journal', 'the-washington-post', 'time',
#        'usa-today', 'wired-de'], dtype=object)

# %%
# Print out the url of the first story for each news source
for source in np.unique(newsfuzz_db['source_id']):
    print(newsfuzz_db[newsfuzz_db['source_id'].isin([source])]['article_url'].tolist()[1])
# Out:
# http://www.abc.net.au/news/2017-06-11/theresa-may-backed-by-senior-ministers-as-leadership-on-line/8609060
# http://www.aljazeera.com/news/2017/06/qatar-diplomatic-crisis-latest-updates-170605105550769.html
# https://arstechnica.com/gaming/2017/06/correction-undercounted-usage-data-in-our-xbox-unleashed-analysis/
# https://apnews.com/630b46cb145d465aa5033c77df5346ff
# http://www.bbc.co.uk/news/election-2017-40237813
# http://www.bbc.co.uk/sport/live/cricket/38832592
# http://www.bild.de/regional/berlin/badeunfall/us-amerikaner-in-lebensgefahr-52134562.bild.html
# https://www.bloomberg.com/politics/articles/2017-06-10/france-elects-parliament-as-macron-aims-to-consolidate-his-power
# http://www.breitbart.com/big-government/2017/06/11/donald-trump-ridicules-cowardly-leaker-james-comey/
# http://www.businessinsider.com/preet-bharara-unusual-interactions-trump-2017-6
# http://uk.businessinsider.com/theresa-may-begins-post-election-reshuffle-2017-6
# https://www.buzzfeed.com/whitneyjefferson/summer-grilling-for-vegetarians-and-vegans
# http://www.cnbc.com/2017/06/11/airport-security-lines-may-get-longer-as-tsa-tests-tighter-security.html
# http://www.cnn.com/videos/world/2017/05/16/poverty-in-venezuela-npw-orig-mss.cnn
# http://www.dailymail.co.uk/news/article-4592078/Victim-told-police-officer-save-London-Bridge.html
# https://www.engadget.com/2017/06/10/star-wars-battlefront-ii-campaign-story-e3-2017/
# http://ew.com/tv/2017/06/11/amy-schumer-celebrity-family-feud/
# http://www.espn.com/espn/feature/story/_/id/19444318/the-unthinkable-fate-chapecoense
# http://www.espncricinfo.com/icc-champions-trophy-2017/content/story/1102718.html
# https://www.ft.com/content/f8b09872-4d2e-11e7-a3f4-c742b9791d43
# http://www.focus.de/politik/ausland/buch-von-sara-mit-celia-mercier-sie-behandelten-uns-wie-tiere_id_7231779.html
# http://www.football-italia.net/node/103977
# http://fortune.com/2017/06/10/qatar-supporting-terror-hires-ex-us-attorney-general/
# https://www.fourfourtwo.com/news/bryan-robson-urges-manchester-united-make-flair-signings
# http://www.foxsports.com/nascar/gallery/6-drivers-who-can-win-pocono-raceway-pocono-400-kyle-busch-brad-keselowski-kyle-larson-kevin-harvick-martin-truex-jr-kurt-busch-monster-energy-series-061117
# http://www.mirror.co.uk/news/politics/uk-politics-poll-tracker-2017-10266121
# http://www.ngin-food.com/artikel/food-essen-trend-printing-vertical-farming
# https://github.com/mimoo/GoKangarooTwelve
# http://ca.ign.com/articles/2017/06/11/e3-2017-star-wars-battlefront-2s-campaign-is-on-the-right-track
# http://www.independent.co.uk/news/uk/politics/dup-theresa-may-northern-ireland-gay-marriage-abortion-enda-kenny-theresa-may-a7784391.html
# http://mashable.com/2017/06/11/weird-body-things/
# http://metro.co.uk/2017/06/11/jeremy-corbyn-says-he-will-topple-theresa-may-within-a-matter-of-days-6700873/
# http://www.mirror.co.uk/tv/tv-news/big-brothers-arthur-fulford-leaves-10604678
# http://www.mtv.com/news/3019002/which-wonder-woman-wore-it-best/
# http://www.mtv.co.uk/james-corden/news/james-corden-shares-heartfelt-tribute-following-attack-at-ariana-grande-manchester-concert
# http://news.nationalgeographic.com/2017/06/vaquita-mexico-fishing-agreement-marine-environment.html
# https://www.newscientist.com/article/2134009-crumb-free-bread-will-mean-iss-astronauts-can-now-bake-in-space/
# http://nymag.com/daily/intelligencer/2017/06/the-fall-of-theresa-may-and-donald-trump.html
# http://www.newsweek.com/north-korea-kim-jong-un-missile-tests-intercontinental-ballistic-missile-us-623801
# http://www.nfl.com/news/story/0ap3000000814393/article/redskins-will-ride-hot-hand-at-running-back-says-oc
# https://www.polygon.com/e3/2017/6/11/15778018/e3-2017-star-wars-battlefront-2-starfighter-gameplay-preview
# https://www.recode.net/2017/6/10/15776384/grand-tour-richard-hammond-car-crash-injured-amazon
# https://gfycat.com/gifs/detail/UnimportantIdleHoneycreeper
# http://www.reuters.com/article/us-usa-progressives-idUSKBN192052
# http://www.spiegel.de/spiegel/politischer-protest-wenn-linke-ploetzlich-rechts-abdriften-a-1151482.html
# http://t3n.de/news/rewe-chef-amazonfresh-wird-keinen-boom-ausloesen-829385/
# http://talksport.com/football/listen-they-have-been-absolutely-magnificent-day-one-england-under-20s-boss-paul-simpson
# https://techcrunch.com/gallery/ea-announces-star-wars-battlefront-ii-madden-18-and-more-new-games-from-e3-2017/
# http://www.techradar.com/news/phone-and-communications/mobile-phones/oneplus-4-1323943
# http://www.economist.com/news/leaders/21723191-conservatives-botched-campaign-will-bring-chaosand-opportunities-theresa-mays-failed-gamble
# https://www.theguardian.com/media/2017/jun/11/peter-dutton-pressures-labor-to-support-coalitions-citizenship-crackdown
# https://www.theguardian.com/uk-news/2017/jun/11/manchester-attack-police-salman-abedi-hashem-ariana-grande
# http://www.thehindu.com/news/national/shivraj-singh-chouhan-calls-off-fast/article18959927.ece
# http://www.huffingtonpost.com/entry/fired-prosecutor-says-he-refused-trumps-call-and-lost-job-the-next-day_us_593d450be4b0c5a35ca04e24
# http://www.ladbible.com/more/uk-inside-the-2m-a-year-cannabis-factory-hidden-in-nuclear-bunker-20170611
# https://www.nytimes.com/2017/06/10/us/politics/politics-religion-liberal-william-barber.html
# http://www.sportbible.com/football/news-take-a-bow-skills-watch-englands-sheyi-ojo-might-be-the-fastest-player-in-football-20170611
# http://www.telegraph.co.uk/news/2017/06/11/donald-trump-state-visit-delayed-president-told-pm-will-not/
# http://timesofindia.indiatimes.com/india/aadhaar-one-of-measures-to-tackle-corruption-black-money-supreme-court/articleshow/59074954.cms
# https://www.theverge.com/2017/6/10/15776370/microsoft-xbox-one-s-price-drop-e3-2017
# https://www.wsj.com/articles/uber-board-to-discuss-ceo-travis-kalanicks-possible-leave-of-absence-1497172226
# https://www.washingtonpost.com/news/post-politics/wp/2017/06/11/trump-i-believe-the-james-comey-leaks-will-be-far-more-prevalent-than-anyone-ever-thought-possible/
# http://time.com/4813668/theresa-may-chiefs-of-staff-resign-uk-election/
# https://www.usatoday.com/story/news/world/2017/06/11/photos-show-bloodied-fake-suicide-belts-worn-london-bridge-attackers/102749796/
# https://www.wired.de/collection/life/electronic-entertainment-expo-e3-scorpio-oculus-rift-sony-switch-playstation-5

# %% [markdown]
# ***The 'done list' (with parsers written):***
#
# ABC News Australia <br/>
# BBC News <br/>
# Daily Mail <br/>
# Reuters <br/>
# The Guardian <br/>
# The Mirror <br/>
# The Telegraph<br/>

# %%
def get_soup(url):
    res = requests.get(url)
    res.raise_for_status()
    return BeautifulSoup(res.text,'lxml')

# %%
def parse_news(url):
    # get soup
    try:
        s= get_soup(url)
        for script in s(["script", "style"]):
            script.extract()
        text=''
        # determine which parser to use
        if 'dailymail.co.uk' in url:
            text=s.find('div',attrs={"itemprop":"articleBody"}).text.replace('\n', '')
        if 'bbc.co.uk/news' in url:
            text=s.find('div',attrs={"class":"story-body__inner"}).text.replace('\n', '')
        if 'abc.net.au' in url:
            text=s.find('div',attrs={"class":"article section"}).text.replace('\n', '')
        if 'theguardian.com' in url:
            text=s.find('div',attrs={"itemprop":"articleBody"}).text.replace('\n', '')
        if 'telegraph.co.uk' in url:
            text=s.find('div',attrs={"class":"article__content js-article"}).text.replace('\n', '')
        if 'mirror.co.uk' in url:
            text=s.find('div',attrs={"class":"article-body"}).text.replace('\n', '')
        if 'reuters.com' in url:
            text=s.find('span',attrs={"id":"article-text"}).text.replace('\n', '')   
        if 'breitbart.com' in url:
            text=s.find('div',attrs={"class":"entry-content"}).text.replace('\n', '')  
    except Exception as exc:
            print(exc)
    return text

# %%
parse_news('http://www.breitbart.com/big-government/2017/06/11/donald-trump-ridicules-cowardly-leaker-james-comey/')
# Out:
# 'President Donald Trump continued to cast doubt on the Senate testimony from his former FBI director James Comey, suggesting that his reliance on leaks to the media was longstanding.“I believe the James Comey leaks will be far more prevalent than anyone ever thought possible,” Trump wrote on Twitter on Sunday.advertisementHe questioned whether Comey’s decision to leak details of his conversation with the president was illegal and cited the FBI director’s own testimony by calling him “very ‘cowardly.’”During the testimony, Comey was asked by Sen. Dianne Feinstein why he told the president that “would see what we could do” when he asked the FBI director to help “lift the cloud” of the Russian investigation off of his administration.“Well, it was kind of a slightly cowardly way of trying to avoid telling him, we’re not going to do that — that I would see what we could do,” Comey replied. “It was a way of kind of getting off the phone, frankly.”Feinstein also asked Comey why he didn’t challenge the president defending his former National Security Advisor Michael Flynn, when he believed that Trump was urging him to drop the investigation.“Maybe if I were stronger, I would have,” Comey said. “I was so stunned by the conversation that I just took it in.”'

# %%
# articles=newsfuzz_db[newsfuzz_db['source_id'].isin(['the-guardian-uk','daily-mail','bbc-news','abc-news-au','mirror','the-telegraph'])]
articles_gdn=newsfuzz_db[newsfuzz_db['source_id'].isin(['the-guardian-uk'])]

articles_gdn.head()
# Out:
#               article_author  \
# index
# 475         Harriet Sherwood
# 476            Josh Halliday
# 477    Hannah Ellis-Petersen
# 478         Philip Oltermann
# 479            Ed Pilkington
#
#                                      article_description  \
# index
# 475    Dean recalls âliving nightmareâ of events ...
# 476    Police say Hashem Abedi travelled to Libya wit...
# 477    Former Top Gear presenter climbed out of vehic...
# 478    Pilot on flight from Ljubljana made unschedule...
# 479    Fifth such vote in 50 years comes after electi...
#
#         article_publishedAt  \
# index
# 475    2017-06-11T13:52:48Z
# 476    2017-06-11T15:22:51Z
# 477    2017-06-11T14:26:18Z
# 478    2017-06-11T14:32:35Z
# 479    2017-06-11T12:01:36Z
#
#                                              article_raw  \
# index
# 475    Southwark Cathedral reopens after London Bridg...
# 476    Manchester attack police to question brother o...
# 477    Richard Hammond escaped crashed car moments be...
# 478    Three detained after London bound easyJet flig...
# 479    Puerto Rico heads to polls in referendum on be...
#
#                                            article_title  \
# index
# 475    Southwark Cathedral reopens after London Bridg...
# 476    Manchester attack: police to question brother ...
# 477    Richard Hammond escaped crashed car moments be...
# 478    Three detained after London-bound easyJet flig...
# 479    Puerto Rico heads to polls in referendum on be...
#
#                                              article_url  \
# index
# 475    https://www.theguardian.com/uk-news/2017/jun/1...
# 476    https://www.theguardian.com/uk-news/2017/jun/1...
# 477    https://www.theguardian.com/tv-and-radio/2017/...
# 478    https://www.theguardian.com/business/2017/jun/...
# 479    https://www.theguardian.com/world/2017/jun/11/...
#
#                                       article_urlToImage source_category  \
# index
# 475    https://i.guim.co.uk/img/media/6043b9d959c958f...         general
# 476    https://i.guim.co.uk/img/media/5894c011f617d3c...         general
# 477    https://i.guim.co.uk/img/media/ba3e3bb9bc97add...         general
# 478    https://i.guim.co.uk/img/media/876bd0c84e8f4db...         general
# 479    https://i.guim.co.uk/img/media/1b92a6c913aae55...         general
#
#       source_country                                 source_description  \
# index
# 475               gb  Latest news, sport, business, comment, analysi...
# 476               gb  Latest news, sport, business, comment, analysi...
# 477               gb  Latest news, sport, business, comment, analysi...
# 478               gb  Latest news, sport, business, comment, analysi...
# 479               gb  Latest news, sport, business, comment, analysi...
#
#              source_id source_language        source_name  \
# index
# 475    the-guardian-uk              en  The Guardian (UK)
# 476    the-guardian-uk              en  The Guardian (UK)
# 477    the-guardian-uk              en  The Guardian (UK)
# 478    the-guardian-uk              en  The Guardian (UK)
# 479    the-guardian-uk              en  The Guardian (UK)
#
#                            source_url
# index
# 475    https://www.theguardian.com/uk
# 476    https://www.theguardian.com/uk
# 477    https://www.theguardian.com/uk
# 478    https://www.theguardian.com/uk
# 479    https://www.theguardian.com/uk

# %%
gdn_urls=articles_gdn['article_url'].tolist()

# %%
def get_articles(url_list):
    articles_text=[]
    count=0
    for u in urls:
        count=count+1
        if count % 10 == 0:
            print(str(count)+' articles from a total of '+str(len(url_list)))
        articles_text.append(parse_news(u))
    return articles_text

# %%
articles_text=get_articles(gdn_urls)
# Out:
# 10 articles from a total of 183
# 20 articles from a total of 183
# 30 articles from a total of 183
# 40 articles from a total of 183
# 50 articles from a total of 183
# 60 articles from a total of 183
# 70 articles from a total of 183
# 80 articles from a total of 183
# 90 articles from a total of 183
# 100 articles from a total of 183
# 110 articles from a total of 183
# 120 articles from a total of 183
# 130 articles from a total of 183
# 140 articles from a total of 183
# 150 articles from a total of 183
# 160 articles from a total of 183
# 170 articles from a total of 183
# 180 articles from a total of 183

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import NMF, LatentDirichletAllocation
from nltk.corpus import stopwords

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
# documents = articles_guard_dm
documents=articles_text
stop = set(stopwords.words('english'))
no_features = 1000

# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words=stop)
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words=stop)
tf = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

no_topics = 10

# Run NMF
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)

# Run LDA
lda = LatentDirichletAllocation(n_topics=no_topics, max_iter=50, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

no_top_words = 10
display_topics(nmf, tfidf_feature_names, no_top_words)
#display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# police people one would us london two year attack facebook
# Topic 1:
# brexit eu government uk election deal may customs negotiations union
# Topic 2:
# trump president sessions comey mueller russia investigation russian washington attorney
# Topic 3:
# inflation plusshareshare postfacebooktwittergoogle prices bank rates rate pay growth pound
# Topic 4:
# cox jo together events mp weekend get communities people think
# Topic 5:
# debt greece imf greek bailout relief eurozone finance programme minister
# Topic 6:
# court treatment judge parents life manchester street child trial family
# Topic 7:
# qatar saudi al foreign states groups terrorism support united food
# Topic 8:
# party farron leader lib liberal campaign election dem views seats
# Topic 9:
# dup ireland northern deal abortion government talks agreement queen may
